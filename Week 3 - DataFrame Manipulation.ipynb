# %% [markdown]
# ## Week 3 - More on Pandas

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pkmn = pd.read_csv("pokemon_long.csv")
type(pkmn)
# Out:
# pandas.core.frame.DataFrame

# %%
#Dataset imports
pkmn = pd.read_csv("pokemon_long.csv")
pkmn.index = pkmn.name
pkmn.head()
# Out:
#                               abilities  against_bug  against_dark  \
# name
# Bulbasaur   ['Overgrow', 'Chlorophyll']          1.0           1.0
# Ivysaur     ['Overgrow', 'Chlorophyll']          1.0           1.0
# Venusaur    ['Overgrow', 'Chlorophyll']          1.0           1.0
# Charmander     ['Blaze', 'Solar Power']          0.5           1.0
# Charmeleon     ['Blaze', 'Solar Power']          0.5           1.0
#
#             against_dragon  against_electric  against_fairy  against_fight  \
# name
# Bulbasaur              1.0               0.5            0.5            0.5
# Ivysaur                1.0               0.5            0.5            0.5
# Venusaur               1.0               0.5            0.5            0.5
# Charmander             1.0               1.0            0.5            1.0
# Charmeleon             1.0               1.0            0.5            1.0
#
#             against_fire  against_flying  against_ghost  ...  percentage_male  \
# name                                                     ...
# Bulbasaur            2.0             2.0            1.0  ...             88.1
# Ivysaur              2.0             2.0            1.0  ...             88.1
# Venusaur             2.0             2.0            1.0  ...             88.1
# Charmander           0.5             1.0            1.0  ...             88.1
# Charmeleon           0.5             1.0            1.0  ...             88.1
#
#             pokedex_number  sp_attack  sp_defense  speed  type1   type2  \
# name
# Bulbasaur                1         65          65     45  grass  poison
# Ivysaur                  2         80          80     60  grass  poison
# Venusaur                 3        122         120     80  grass  poison
# Charmander               4         60          50     65   fire     NaN
# Charmeleon               5         80          65     80   fire     NaN
#
#             weight_kg  generation  is_legendary
# name
# Bulbasaur         6.9           1             0
# Ivysaur          13.0           1             0
# Venusaur        100.0           1             0
# Charmander        8.5           1             0
# Charmeleon       19.0           1             0
#
# [5 rows x 41 columns]

# %%
#           help(pkmn.head)   #everyone in python is an object

# %%
#           pkmn.attack.value_counts

# %%
#extra examples from class 

#template 
class Person:
    
    
#attributes/properties 
    age 
    height
    weight 
    
    #methods 
    walk()
    run()
    talk()
    
# object orients programming:

# andy = Peson()

#def

# %%
econ = sm.datasets.macrodata.load_pandas().data
econ.head()
# Out:
#      year  quarter   realgdp  realcons  realinv  realgovt  realdpi    cpi  \
# 0  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9  28.98
# 1  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7  29.15
# 2  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4  29.35
# 3  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3  29.37
# 4  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5  29.54
#
#       m1  tbilrate  unemp      pop  infl  realint
# 0  139.7      2.82    5.8  177.146  0.00     0.00
# 1  141.7      3.08    5.1  177.830  2.34     0.74
# 2  140.5      3.82    5.3  178.657  2.74     1.09
# 3  140.0      4.33    5.6  179.386  0.27     4.06
# 4  139.6      3.50    5.2  180.007  2.31     1.19

# %%
econ.plot()   #.plot is a mehtod
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(15, 5))
econ.plot(ax=ax)
plt.title("US Economic Data")
# Out:
# Text(0.5, 1.0, 'US Economic Data')

# %%
econ.assign(pop_change = econ['pop'].diff()) 
econ.head()
# Out:
#      year  quarter   realgdp  realcons  realinv  realgovt  realdpi    cpi  \
# 0  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9  28.98
# 1  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7  29.15
# 2  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4  29.35
# 3  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3  29.37
# 4  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5  29.54
#
#       m1  tbilrate  unemp      pop  infl  realint
# 0  139.7      2.82    5.8  177.146  0.00     0.00
# 1  141.7      3.08    5.1  177.830  2.34     0.74
# 2  140.5      3.82    5.3  178.657  2.74     1.09
# 3  140.0      4.33    5.6  179.386  0.27     4.06
# 4  139.6      3.50    5.2  180.007  2.31     1.19

# %% [markdown]
# ### Section 1: Advanced Methods & Operations

# %% [markdown]
# With DataFrames, there are some more advanced methods that you should be aware of:
# <ol>
# <li> .query()</li>
# <li> .assign()</li>
# <li> .any()</li>
# <li> .all()</li>
# <li> .apply()</li>
#
#
#
# </ol>

# %%
# The .query() method allows you to filter rows in a DataFrame based on a specified condition.
    # df.query('age > 30')


# The .assign() method is used to create new columns or modify existing ones in a DataFrame.
    # df.assign(total=df['column1'] + df['column2'])


# The .any() method checks if at least one element in a DataFrame or Series evaluates to True.
    # df['column'].any()  # Returns True if at least one value in 'column' is True.


# The .all() method checks if all elements in a DataFrame or Series evaluate to True.
# It returns a boolean value (True or False).
    # df['column'].all()  # Returns True if all values in 'column' are True.


# The .apply() method is used to apply a custom function to each element or column in a DataFrame.
    # def square(x):
    #     return x ** 2
    # df['column'].apply(square)  # Applies the 'square' function to each element in 'column'.

# %%
#properties -- begin with df.index
index
shape
axes
columns
values
dtypes



#methods  -- begin with df.head()
head()
tail()
info()
describe()
nunique()
value_counts()
isna() / isnull()   -- Check for missing (NaN) values in the DataFrame.
mean()              --- average
median()            --middle 
min()
max()
std()
corr()
groupby()

# %%
A pandas Series is a one-dimensional labeled array capable of holding data of various types. 
You can calculate the mean of a Series using the .mean() method. 

Boolean masking involves creating a mask, which is a Series of boolean values that can be used to filter data.

Example -- Series called grades
grades = pd.Series([90, 85, 88, 92, 78, 95, 87, 91, 82, 89])

Example -- Boolean and apply a condition on series 
mask = grades >= 90

# %%
#boolean masking -- examples

#pkmn.attack  #

#pkmn.query("attack > 200 ")

pkmn[pkmn.attack > 150]   ###this is a boolean mask -- apply a condition ex: > 150
# Out:
#                                            abilities  against_bug  \
# name
# Pinsir     ['Hyper Cutter', 'Mold Breaker', 'Moxie']         1.00
# Gyarados                     ['Intimidate', 'Moxie']         0.50
# Heracross                 ['Swarm', 'Guts', 'Moxie']         0.50
# Tyranitar                 ['Sand Stream', 'Unnerve']         2.00
# Blaziken                    ['Blaze', 'Speed Boost']         0.25
# Slaking                                   ['Truant']         1.00
# Banette         ['Insomnia', 'Frisk', 'Cursed Body']         0.50
# Groudon                                  ['Drought']         1.00
# Rayquaza                                ['Air Lock']         0.50
# Rampardos            ['Mold Breaker', 'Sheer Force']         1.00
# Garchomp                 ['Sand Veil', 'Rough Skin']         1.00
# Gallade                   ['Steadfast', 'Justified']         1.00
# Regigigas                             ['Slow Start']         1.00
# Diancie                               ['Clear Body']         0.50
# Hoopa                                   ['Magician']         1.00
# Kartana                              ['Beast Boost']         1.00
#
#            against_dark  against_dragon  against_electric  against_fairy  \
# name
# Pinsir              1.0             1.0               1.0            1.0
# Gyarados            1.0             1.0               4.0            1.0
# Heracross           0.5             1.0               1.0            2.0
# Tyranitar           0.5             1.0               1.0            2.0
# Blaziken            0.5             1.0               1.0            1.0
# Slaking             1.0             1.0               1.0            1.0
# Banette             2.0             1.0               1.0            1.0
# Groudon             1.0             1.0               0.0            1.0
# Rayquaza            1.0             2.0               1.0            2.0
# Rampardos           1.0             1.0               1.0            1.0
# Garchomp            1.0             2.0               0.0            2.0
# Gallade             1.0             1.0               1.0            2.0
# Regigigas           1.0             1.0               1.0            1.0
# Diancie             0.5             0.0               1.0            1.0
# Hoopa               4.0             1.0               1.0            1.0
# Kartana             1.0             0.5               0.5            0.5
#
#            against_fight  against_fire  against_flying  against_ghost  ...  \
# name                                                                   ...
# Pinsir               0.5           2.0             2.0            1.0  ...
# Gyarados             0.5           0.5             1.0            1.0  ...
# Heracross            0.5           2.0             4.0            1.0  ...
# Tyranitar            4.0           0.5             0.5            0.5  ...
# Blaziken             1.0           0.5             2.0            1.0  ...
# Slaking              2.0           1.0             1.0            0.0  ...
# Banette              0.0           1.0             1.0            2.0  ...
# Groudon              1.0           1.0             1.0            1.0  ...
# Rayquaza             0.5           0.5             1.0            1.0  ...
# Rampardos            2.0           0.5             0.5            1.0  ...
# Garchomp             1.0           0.5             1.0            1.0  ...
# Gallade              0.5           1.0             2.0            2.0  ...
# Regigigas            2.0           1.0             1.0            0.0  ...
# Diancie              1.0           0.5             0.5            1.0  ...
# Hoopa                0.0           1.0             1.0            4.0  ...
# Kartana              2.0           4.0             1.0            1.0  ...
#
#            percentage_male  pokedex_number  sp_attack  sp_defense  speed  \
# name
# Pinsir                50.0             127         65          90    105
# Gyarados              50.0             130         70         130     81
# Heracross             50.0             214         40         105     75
# Tyranitar             50.0             248         95         120     71
# Blaziken              88.1             257        130          80    100
# Slaking               50.0             289         95          65    100
# Banette               50.0             354         93          83     75
# Groudon                NaN             383        150          90     90
# Rayquaza               NaN             384        180         100    115
# Rampardos             88.1             409         65          50     58
# Garchomp              50.0             445        120          95     92
# Gallade              100.0             475         65         115    110
# Regigigas              NaN             486         80         110    100
# Diancie                NaN             719        160         110    110
# Hoopa                  NaN             720        170         130     80
# Kartana                NaN             798         59          31    109
#
#              type1     type2  weight_kg  generation  is_legendary
# name
# Pinsir         bug       NaN       55.0           1             0
# Gyarados     water    flying      235.0           1             0
# Heracross      bug  fighting       54.0           2             0
# Tyranitar     rock      dark      202.0           2             0
# Blaziken      fire  fighting       52.0           3             0
# Slaking     normal       NaN      130.5           3             0
# Banette      ghost       NaN       12.5           3             0
# Groudon     ground       NaN      950.0           3             1
# Rayquaza    dragon    flying      206.5           3             1
# Rampardos     rock       NaN      102.5           4             0
# Garchomp    dragon    ground       95.0           4             0
# Gallade    psychic  fighting       52.0           4             0
# Regigigas   normal       NaN      420.0           4             1
# Diancie       rock     fairy        8.8           6             1
# Hoopa      psychic     ghost        NaN           6             1
# Kartana      grass     steel        0.1           7             1
#
# [16 rows x 41 columns]

# %%
#show me all the data in the columns

pkmn.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
#fire, flying
#squirtle = > water 

#this is a object and create a different databframe.  does not equal pkmn dataframe.  
#if you want to change the pkmn dataframe then you need to indicate pkmn = pkmn.assign....,

        # pkmn.assign(
        #     more_than_1_type = ~ pkmn.type2.isna(),
        #     avg_defense = (pkmn.defense + pkmn.sp_defense)/2
        # )

        # pkmn.head()

#syntax is a different dataframe and is not part or updates the ECON dataframe. 
    #econ.assign(pop_change = econ['pop'].diff())

#to update the ECON dataframe for the above syntax you need to assign ECON or add ",inplace = True" 
econ = econ.assign(
        pop_change = econ['pop'].diff()
)
econ.head()
# Out:
#      year  quarter   realgdp  realcons  realinv  realgovt  realdpi    cpi  \
# 0  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9  28.98
# 1  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7  29.15
# 2  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4  29.35
# 3  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3  29.37
# 4  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5  29.54
#
#       m1  tbilrate  unemp      pop  infl  realint  pop_change
# 0  139.7      2.82    5.8  177.146  0.00     0.00         NaN
# 1  141.7      3.08    5.1  177.830  2.34     0.74       0.684
# 2  140.5      3.82    5.3  178.657  2.74     1.09       0.827
# 3  140.0      4.33    5.6  179.386  0.27     4.06       0.729
# 4  139.6      3.50    5.2  180.007  2.31     1.19       0.621

# %%
pkmn.columns         #displays all the columns from the pkmn dataframe
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
pkmn.is_legendary = 1 #is this switch on (1) or off (0) 
                      #         True            False

# %%
(pkmn.is_legendary == 1).sum()   #sums all the values that are TRUE
# Out:
# 801

# %%
pkmn.is_legendary.any()    #returns TRUE is any of the values in the series is TRUE
# Out:
# True

# %%
pkmn.type1.isna()         #find missing values in my data.  TRUE = missing.  FALSE = not missing
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 796    False
# 797    False
# 798    False
# 799    False
# 800    False
# Name: type1, Length: 801, dtype: bool

# %%
pkmn.type2.isna().any()   #any checks for if ANY values is TRUE.  TRUE is missing.  FALSE = not missing
# Out:
# True

# %%
#pkmn.height_m   <<<--this is a series 

#type(pkmn.height_m >= 20)   <<---will indicate below is a boolean series 

(pkmn.height_m >= 20) #BOOLEAN #search column on condition if >= 20.  returns a boolean series TRUE or FALSE 

    #pkmn[pkmn.height_m >= 1]   see below. BOOLEAN MAKSING
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 796    False
# 797    False
# 798    False
# 799    False
# 800    False
# Name: height_m, Length: 801, dtype: bool

# %%
#this is BOOLEAN MASKING

pkmn[pkmn.height_m >= 1]    #if you want to return data you need to reference the df pkmn and surround the condiditon in brackets
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 5       ['Blaze', 'Solar Power']         0.25           1.0             1.0
# 7       ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# ..                           ...          ...           ...             ...
# 795              ['Beast Boost']         1.00           1.0             1.0
# 796              ['Beast Boost']         0.25           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 1                 0.5            0.5            0.5           2.0
# 2                 0.5            0.5            0.5           2.0
# 4                 1.0            0.5            1.0           0.5
# 5                 2.0            0.5            0.5           0.5
# 7                 2.0            1.0            1.0           0.5
# ..                ...            ...            ...           ...
# 795               0.5            1.0            1.0           1.0
# 796               2.0            0.5            1.0           2.0
# 798               0.5            4.0            2.0           0.5
# 799               1.0            1.0            0.5           1.0
# 800               1.0            0.5            1.0           2.0
#
#      against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 1               2.0            1.0  ...             88.1               2
# 2               2.0            1.0  ...             88.1               3
# 4               1.0            1.0  ...             88.1               5
# 5               1.0            1.0  ...             88.1               6
# 7               1.0            1.0  ...             88.1               8
# ..              ...            ...  ...              ...             ...
# 795             0.5            1.0  ...              NaN             796
# 796             0.5            1.0  ...              NaN             797
# 798             1.0            0.5  ...              NaN             799
# 799             1.0            2.0  ...              NaN             800
# 800             0.5            1.0  ...              NaN             801
#
#      sp_attack  sp_defense  speed     type1   type2  weight_kg  generation  \
# 1           80          80     60     grass  poison       13.0           1
# 2          122         120     80     grass  poison      100.0           1
# 4           80          65     80      fire     NaN       19.0           1
# 5          159         115    100      fire  flying       90.5           1
# 7           65          80     58     water     NaN       22.5           1
# ..         ...         ...    ...       ...     ...        ...         ...
# 795        173          71     83  electric     NaN      100.0           7
# 796        107         101     61     steel  flying      999.9           7
# 798         97          53     43      dark  dragon      888.0           7
# 799        127          89     79   psychic     NaN      230.0           7
# 800        130         115     65     steel   fairy       80.5           7
#
#      is_legendary
# 1               1
# 2               1
# 4               1
# 5               1
# 7               1
# ..            ...
# 795             1
# 796             1
# 798             1
# 799             1
# 800             1
#
# [405 rows x 41 columns]

# %%
pkmn.type2.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 796    False
# 797    False
# 798    False
# 799     True
# 800    False
# Name: type2, Length: 801, dtype: bool

# %%
pkmn.loc

# %%
#the .any()method
#classes hae properties and methods

    # Series
    # DataFrame

# %%
type(econ['pop'])
# Out:
# pandas.core.series.Series

# %%
pkmn.abilities
# Out:
# 0      ['Overgrow', 'Chlorophyll']
# 1      ['Overgrow', 'Chlorophyll']
# 2      ['Overgrow', 'Chlorophyll']
# 3         ['Blaze', 'Solar Power']
# 4         ['Blaze', 'Solar Power']
#                   ...
# 796                ['Beast Boost']
# 797                ['Beast Boost']
# 798                ['Beast Boost']
# 799                ['Prism Armor']
# 800                 ['Soul-Heart']
# Name: abilities, Length: 801, dtype: object

# %%
#apply 

#elementwise 
def count_abilities(x):
    #x is each element of the series 
    
    abilities = eval(x)
    return len(abilities)

#function is an object 
#verythng is an object
pkmn.abilities.apply(count_abilities).value_counts()

#
pkmn.select_dtypes('object').apply(lambda x: x.str.upper())

#aggregate down columns or across rows
# Out:
#                        abilities capture_rate        classfication  \
# 0    ['OVERGROW', 'CHLOROPHYLL']           45         SEED POKÉMON
# 1    ['OVERGROW', 'CHLOROPHYLL']           45         SEED POKÉMON
# 2    ['OVERGROW', 'CHLOROPHYLL']           45         SEED POKÉMON
# 3       ['BLAZE', 'SOLAR POWER']           45       LIZARD POKÉMON
# 4       ['BLAZE', 'SOLAR POWER']           45        FLAME POKÉMON
# ..                           ...          ...                  ...
# 796              ['BEAST BOOST']           25       LAUNCH POKÉMON
# 797              ['BEAST BOOST']          255  DRAWN SWORD POKÉMON
# 798              ['BEAST BOOST']           15    JUNKIVORE POKÉMON
# 799              ['PRISM ARMOR']            3        PRISM POKÉMON
# 800               ['SOUL-HEART']            3   ARTIFICIAL POKÉMON
#
#         japanese_name        name    type1   type2
# 0    FUSHIGIDANEフシギダネ   BULBASAUR    GRASS  POISON
# 1     FUSHIGISOUフシギソウ     IVYSAUR    GRASS  POISON
# 2    FUSHIGIBANAフシギバナ    VENUSAUR    GRASS  POISON
# 3        HITOKAGEヒトカゲ  CHARMANDER     FIRE     NaN
# 4         LIZARDOリザード  CHARMELEON     FIRE     NaN
# ..                ...         ...      ...     ...
# 796    TEKKAGUYAテッカグヤ  CELESTEELA    STEEL  FLYING
# 797   KAMITURUGIカミツルギ     KARTANA    GRASS   STEEL
# 798   AKUZIKINGアクジキング    GUZZLORD     DARK  DRAGON
# 799     NECROZMAネクロズマ    NECROZMA  PSYCHIC     NaN
# 800      MAGEARNAマギアナ    MAGEARNA    STEEL   FAIRY
#
# [801 rows x 7 columns]

# %%
np.round(pkmn.select_dtypes(np.number).apply(np.mean, axis = 0),2)  #0 = column #1 = rows 

#pd.Dataframe.apply()
# Out:
# against_bug                1.00
# against_dark               1.06
# against_dragon             0.97
# against_electric           1.07
# against_fairy              1.07
# against_fight              1.07
# against_fire               1.14
# against_flying             1.19
# against_ghost              0.99
# against_grass              1.03
# against_ground             1.10
# against_ice                1.21
# against_normal             0.89
# against_poison             0.98
# against_psychic            1.01
# against_rock               1.25
# against_steel              0.98
# against_water              1.06
# attack                    77.86
# base_egg_steps          7191.01
# base_happiness            65.36
# base_total               428.38
# defense                   73.01
# experience_growth    1054995.91
# height_m                   1.16
# hp                        68.96
# percentage_male           55.16
# pokedex_number           401.00
# sp_attack                 71.31
# sp_defense                70.91
# speed                     66.33
# weight_kg                 61.38
# generation                 3.69
# is_legendary               0.09
# dtype: float64

# %%
#The .query method is like the boolean filtering we did last week.
# .query() is just sometimes shorter than writing a lot of boolean masks.

#Example
pkmn.query("name.str.startswith('M')")

#Example with economic data
econ.query("realint > 4")
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File ~\anaconda3\Lib\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~\anaconda3\Lib\site-packages\IPython\lib\pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1064, in DataFrame.__repr__(self)
#    1061     return buf.getvalue()
#    1063 repr_params = fmt.get_dataframe_repr_params()
# -> 1064 return self.to_string(**repr_params)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1245, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1226 with option_context("display.max_colwidth", max_colwidth):
#    1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    (...)
#    1243         decimal=decimal,
#    1244     )
# -> 1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
#    1248         line_width=line_width,
#    1249     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1136, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1133 from pandas.io.formats.string import StringFormatter
#    1135 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136 string = string_formatter.to_string()
#    1137 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\string.py:30, in StringFormatter.to_string(self)
#      29 def to_string(self) -> str:
# ---> 30     text = self._get_string_representation()
#      31     if self.fmt.should_show_dimensions:
#      32         text = "".join([text, self.fmt.dimensions_info])
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\string.py:45, in StringFormatter._get_string_representation(self)
#      42 if self.fmt.frame.empty:
#      43     return self._empty_info_line
# ---> 45 strcols = self._get_strcols()
#      47 if self.line_width is None:
#      48     # no need to wrap around just print the whole frame
#      49     return self.adj.adjoin(1, *strcols)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\string.py:36, in StringFormatter._get_strcols(self)
#      35 def _get_strcols(self) -> list[list[str]]:
# ---> 36     strcols = self.fmt.get_strcols()
#      37     if self.fmt.is_truncated:
#      38         strcols = self._insert_dot_separators(strcols)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:617, in DataFrameFormatter.get_strcols(self)
#     613 def get_strcols(self) -> list[list[str]]:
#     614     """
#     615     Render a DataFrame to a list of columns (as lists of strings).
#     616     """
# --> 617     strcols = self._get_strcols_without_index()
#     619     if self.index:
#     620         str_index = self._get_formatted_index(self.tr_frame)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:883, in DataFrameFormatter._get_strcols_without_index(self)
#     879 cheader = str_columns[i]
#     880 header_colwidth = max(
#     881     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     882 )
# --> 883 fmt_values = self.format_col(i)
#     884 fmt_values = _make_fixed_width(
#     885     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     886 )
#     888 max_len = max(max(self.adj.len(x) for x in fmt_values), header_colwidth)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1422, in GenericArrayFormatter._format_strings(self)
#    1420 for i, v in enumerate(vals):
#    1421     if not is_float_type[i] and leading_space:
# -> 1422         fmt_values.append(f" {_format(v)}")
#    1423     elif is_float_type[i]:
#    1424         fmt_values.append(float_format(v))
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1402, in GenericArrayFormatter._format_strings.<locals>._format(x)
#    1399     return str(x)
#    1400 else:
#    1401     # object dtype
# -> 1402     return str(formatter(x))
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\printing.py:232, in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     230     result = f"'{as_escaped_string(thing)}'"
#     231 else:
# --> 232     result = as_escaped_string(thing)
#     234 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\printing.py:208, in pprint_thing.<locals>.as_escaped_string(thing, escape_chars)
#     205 else:
#     206     escape_chars = escape_chars or ()
# --> 208 result = str(thing)
#     209 for c in escape_chars:
#     210     result = result.replace(c, translate[c])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1064, in DataFrame.__repr__(self)
#    1061     return buf.getvalue()
#    1063 repr_params = fmt.get_dataframe_repr_params()
# -> 1064 return self.to_string(**repr_params)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1245, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1226 with option_context("display.max_colwidth", max_colwidth):
#    1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    (...)
#    1243         decimal=decimal,
#    1244     )
# -> 1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
#    1248         line_width=line_width,
#    1249     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1136, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1133 from pandas.io.formats.string import StringFormatter
#    1135 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136 string = string_formatter.to_string()
#    1137 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\string.py:30, in StringFormatter.to_string(self)
#      29 def to_string(self) -> str:
# ---> 30     text = self._get_string_representation()
#      31     if self.fmt.should_show_dimensions:
#      32         text = "".join([text, self.fmt.dimensions_info])
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\string.py:45, in StringFormatter._get_string_representation(self)
#      42 if self.fmt.frame.empty:
#      43     return self._empty_info_line
# ---> 45 strcols = self._get_strcols()
#      47 if self.line_width is None:
#      48     # no need to wrap around just print the whole frame
#      49     return self.adj.adjoin(1, *strcols)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\string.py:36, in StringFormatter._get_strcols(self)
#      35 def _get_strcols(self) -> list[list[str]]:
# ---> 36     strcols = self.fmt.get_strcols()
#      37     if self.fmt.is_truncated:
#      38         strcols = self._insert_dot_separators(strcols)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:617, in DataFrameFormatter.get_strcols(self)
#     613 def get_strcols(self) -> list[list[str]]:
#     614     """
#     615     Render a DataFrame to a list of columns (as lists of strings).
#     616     """
# --> 617     strcols = self._get_strcols_without_index()
#     619     if self.index:
#     620         str_index = self._get_formatted_index(self.tr_frame)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:883, in DataFrameFormatter._get_strcols_without_index(self)
#     879 cheader = str_columns[i]
#     880 header_colwidth = max(
#     881     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     882 )
# --> 883 fmt_values = self.format_col(i)
#     884 fmt_values = _make_fixed_width(
#     885     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     886 )
#     888 max_len = max(max(self.adj.len(x) for x in fmt_values), header_colwidth)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1422, in GenericArrayFormatter._format_strings(self)
#    1420 for i, v in enumerate(vals):
#    1421     if not is_float_type[i] and leading_space:
# -> 1422         fmt_values.append(f" {_format(v)}")
#    1423     elif is_float_type[i]:
#    1424         fmt_values.append(float_format(v))
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1402, in GenericArrayFormatter._format_strings.<locals>._format(x)
#    1399     return str(x)
#    1400 else:
#    1401     # object dtype
# -> 1402     return str(formatter(x))
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\printing.py:232, in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     230     result = f"'{as_escaped_string(thing)}'"
#     231 else:
# --> 232     result = as_escaped_string(thing)
#     234 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\printing.py:208, in pprint_thing.<locals>.as_escaped_string(thing, escape_chars)
#     205 else:
#     206     escape_chars = escape_chars or ()
# --> 208 result = str(thing)
#     209 for c in escape_chars:
#     210     result = result.replace(c, translate[c])
#
#     [... skipping similar frames: DataFrame.__repr__ at line 1064 (162 times), GenericArrayFormatter._format_strings.<locals>._format at line 1402 (161 times), GenericArrayFormatter._format_strings at line 1422 (161 times), StringFormatter._get_strcols at line 36 (161 times), DataFrameFormatter._get_strcols_without_index at line 883 (161 times), StringFormatter._get_string_representation at line 45 (161 times), pprint_thing.<locals>.as_escaped_string at line 208 (161 times), format_array at line 1328 (161 times), DataFrameFormatter.format_col at line 897 (161 times), GenericArrayFormatter.get_result at line 1359 (161 times), DataFrameFormatter.get_strcols at line 617 (161 times), pprint_thing at line 232 (161 times), DataFrame.to_string at line 1245 (161 times), DataFrameRenderer.to_string at line 1136 (161 times), StringFormatter.to_string at line 30 (161 times)]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1245, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1226 with option_context("display.max_colwidth", max_colwidth):
#    1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    (...)
#    1243         decimal=decimal,
#    1244     )
# -> 1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
#    1248         line_width=line_width,
#    1249     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1136, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1133 from pandas.io.formats.string import StringFormatter
#    1135 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136 string = string_formatter.to_string()
#    1137 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\string.py:30, in StringFormatter.to_string(self)
#      29 def to_string(self) -> str:
# ---> 30     text = self._get_string_representation()
#      31     if self.fmt.should_show_dimensions:
#      32         text = "".join([text, self.fmt.dimensions_info])
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\string.py:45, in StringFormatter._get_string_representation(self)
#      42 if self.fmt.frame.empty:
#      43     return self._empty_info_line
# ---> 45 strcols = self._get_strcols()
#      47 if self.line_width is None:
#      48     # no need to wrap around just print the whole frame
#      49     return self.adj.adjoin(1, *strcols)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\string.py:36, in StringFormatter._get_strcols(self)
#      35 def _get_strcols(self) -> list[list[str]]:
# ---> 36     strcols = self.fmt.get_strcols()
#      37     if self.fmt.is_truncated:
#      38         strcols = self._insert_dot_separators(strcols)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:617, in DataFrameFormatter.get_strcols(self)
#     613 def get_strcols(self) -> list[list[str]]:
#     614     """
#     615     Render a DataFrame to a list of columns (as lists of strings).
#     616     """
# --> 617     strcols = self._get_strcols_without_index()
#     619     if self.index:
#     620         str_index = self._get_formatted_index(self.tr_frame)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:883, in DataFrameFormatter._get_strcols_without_index(self)
#     879 cheader = str_columns[i]
#     880 header_colwidth = max(
#     881     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     882 )
# --> 883 fmt_values = self.format_col(i)
#     884 fmt_values = _make_fixed_width(
#     885     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     886 )
#     888 max_len = max(max(self.adj.len(x) for x in fmt_values), header_colwidth)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1422, in GenericArrayFormatter._format_strings(self)
#    1420 for i, v in enumerate(vals):
#    1421     if not is_float_type[i] and leading_space:
# -> 1422         fmt_values.append(f" {_format(v)}")
#    1423     elif is_float_type[i]:
#    1424         fmt_values.append(float_format(v))
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1402, in GenericArrayFormatter._format_strings.<locals>._format(x)
#    1399     return str(x)
#    1400 else:
#    1401     # object dtype
# -> 1402     return str(formatter(x))
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\printing.py:232, in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     230     result = f"'{as_escaped_string(thing)}'"
#     231 else:
# --> 232     result = as_escaped_string(thing)
#     234 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\printing.py:208, in pprint_thing.<locals>.as_escaped_string(thing, escape_chars)
#     205 else:
#     206     escape_chars = escape_chars or ()
# --> 208 result = str(thing)
#     209 for c in escape_chars:
#     210     result = result.replace(c, translate[c])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1064, in DataFrame.__repr__(self)
#    1061     return buf.getvalue()
#    1063 repr_params = fmt.get_dataframe_repr_params()
# -> 1064 return self.to_string(**repr_params)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1226, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1193 """
#    1194 Render a DataFrame to a console-friendly tabular output.
#    1195 %(shared_params)s
#    (...)
#    1222 2     3     6
#    1223 """
#    1224 from pandas import option_context
# -> 1226 with option_context("display.max_colwidth", max_colwidth):
#    1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    (...)
#    1243         decimal=decimal,
#    1244     )
#    1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
#    1248         line_width=line_width,
#    1249     )
#
# File ~\anaconda3\Lib\site-packages\pandas\_config\config.py:445, in option_context.__enter__(self)
#     442 self.undo = [(pat, _get_option(pat, silent=True)) for pat, val in self.ops]
#     444 for pat, val in self.ops:
# --> 445     _set_option(pat, val, silent=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\_config\config.py:169, in _set_option(*args, **kwargs)
#     167 if silent:
#     168     with warnings.catch_warnings(record=True):
# --> 169         o.cb(key)
#     170 else:
#     171     o.cb(key)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\config_init.py:393, in _deprecate_negative_int_max_colwidth(key)
#     392 def _deprecate_negative_int_max_colwidth(key):
# --> 393     value = cf.get_option(key)
#     394     if value is not None and value < 0:
#     395         warnings.warn(
#     396             "Passing a negative integer is deprecated in version 1.0 and "
#     397             "will not be supported in future version. Instead, use None "
#    (...)
#     400             stacklevel=find_stack_level(),
#     401         )
#
# File ~\anaconda3\Lib\site-packages\pandas\_config\config.py:263, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     262 def __call__(self, *args, **kwds) -> T:
# --> 263     return self.__func__(*args, **kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\_config\config.py:135, in _get_option(pat, silent)
#     134 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 135     key = _get_single_key(pat, silent)
#     137     # walk the nested dict
#     138     root, k = _get_root(key)
#
# File ~\anaconda3\Lib\site-packages\pandas\_config\config.py:127, in _get_single_key(pat, silent)
#     124 key = keys[0]
#     126 if not silent:
# --> 127     _warn_if_deprecated(key)
#     129 key = _translate_key(key)
#     131 return key
#
# File ~\anaconda3\Lib\site-packages\pandas\_config\config.py:658, in _warn_if_deprecated(key)
#     650 def _warn_if_deprecated(key: str) -> bool:
#     651     """
#     652     Checks if `key` is a deprecated option and if so, prints a warning.
#     653
#    (...)
#     656     bool - True if `key` is deprecated, False otherwise.
#     657     """
# --> 658     d = _get_deprecated_option(key)
#     659     if d:
#     660         if d.msg:
#
# RecursionError: maximum recursion depth exceeded
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1106, in DataFrame._repr_html_(self)
#    1084     show_dimensions = get_option("display.show_dimensions")
#    1086     formatter = fmt.DataFrameFormatter(
#    1087         self,
#    1088         columns=None,
#    (...)
#    1104         decimal=".",
#    1105     )
# -> 1106     return fmt.DataFrameRenderer(formatter).to_html(notebook=True)
#    1107 else:
#    1108     return None
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1110, in DataFrameRenderer.to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#    1101 Klass = NotebookFormatter if notebook else HTMLFormatter
#    1103 html_formatter = Klass(
#    1104     self.fmt,
#    1105     classes=classes,
#    (...)
#    1108     render_links=render_links,
#    1109 )
# -> 1110 string = html_formatter.to_string()
#    1111 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\html.py:77, in HTMLFormatter.to_string(self)
#      76 def to_string(self) -> str:
# ---> 77     lines = self.render()
#      78     if any(isinstance(x, str) for x in lines):
#      79         lines = [str(x) for x in lines]
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\html.py:632, in NotebookFormatter.render(self)
#     630 self.write("<div>")
#     631 self.write_style()
# --> 632 super().render()
#     633 self.write("</div>")
#     634 return self.elements
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\html.py:83, in HTMLFormatter.render(self)
#      82 def render(self) -> list[str]:
# ---> 83     self._write_table()
#      85     if self.should_show_dimensions:
#      86         by = chr(215)  # ×
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\html.py:258, in HTMLFormatter._write_table(self, indent)
#     255 if self.fmt.header or self.show_row_idx_names:
#     256     self._write_header(indent + self.indent_delta)
# --> 258 self._write_body(indent + self.indent_delta)
#     260 self.write("</table>", indent)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\html.py:406, in HTMLFormatter._write_body(self, indent)
#     404 def _write_body(self, indent: int) -> None:
#     405     self.write("<tbody>", indent)
# --> 406     fmt_values = self._get_formatted_values()
#     408     # write values
#     409     if self.fmt.index and isinstance(self.frame.index, MultiIndex):
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\html.py:596, in NotebookFormatter._get_formatted_values(self)
#     595 def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 596     return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\html.py:596, in <dictcomp>(.0)
#     595 def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 596     return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1422, in GenericArrayFormatter._format_strings(self)
#    1420 for i, v in enumerate(vals):
#    1421     if not is_float_type[i] and leading_space:
# -> 1422         fmt_values.append(f" {_format(v)}")
#    1423     elif is_float_type[i]:
#    1424         fmt_values.append(float_format(v))
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1402, in GenericArrayFormatter._format_strings.<locals>._format(x)
#    1399     return str(x)
#    1400 else:
#    1401     # object dtype
# -> 1402     return str(formatter(x))
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\printing.py:232, in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     230     result = f"'{as_escaped_string(thing)}'"
#     231 else:
# --> 232     result = as_escaped_string(thing)
#     234 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\printing.py:208, in pprint_thing.<locals>.as_escaped_string(thing, escape_chars)
#     205 else:
#     206     escape_chars = escape_chars or ()
# --> 208 result = str(thing)
#     209 for c in escape_chars:
#     210     result = result.replace(c, translate[c])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1064, in DataFrame.__repr__(self)
#    1061     return buf.getvalue()
#    1063 repr_params = fmt.get_dataframe_repr_params()
# -> 1064 return self.to_string(**repr_params)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1245, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1226 with option_context("display.max_colwidth", max_colwidth):
#    1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    (...)
#    1243         decimal=decimal,
#    1244     )
# -> 1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
#    1248         line_width=line_width,
#    1249     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1136, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1133 from pandas.io.formats.string import StringFormatter
#    1135 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136 string = string_formatter.to_string()
#    1137 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\string.py:30, in StringFormatter.to_string(self)
#      29 def to_string(self) -> str:
# ---> 30     text = self._get_string_representation()
#      31     if self.fmt.should_show_dimensions:
#      32         text = "".join([text, self.fmt.dimensions_info])
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\string.py:45, in StringFormatter._get_string_representation(self)
#      42 if self.fmt.frame.empty:
#      43     return self._empty_info_line
# ---> 45 strcols = self._get_strcols()
#      47 if self.line_width is None:
#      48     # no need to wrap around just print the whole frame
#      49     return self.adj.adjoin(1, *strcols)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\string.py:36, in StringFormatter._get_strcols(self)
#      35 def _get_strcols(self) -> list[list[str]]:
# ---> 36     strcols = self.fmt.get_strcols()
#      37     if self.fmt.is_truncated:
#      38         strcols = self._insert_dot_separators(strcols)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:617, in DataFrameFormatter.get_strcols(self)
#     613 def get_strcols(self) -> list[list[str]]:
#     614     """
#     615     Render a DataFrame to a list of columns (as lists of strings).
#     616     """
# --> 617     strcols = self._get_strcols_without_index()
#     619     if self.index:
#     620         str_index = self._get_formatted_index(self.tr_frame)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:883, in DataFrameFormatter._get_strcols_without_index(self)
#     879 cheader = str_columns[i]
#     880 header_colwidth = max(
#     881     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     882 )
# --> 883 fmt_values = self.format_col(i)
#     884 fmt_values = _make_fixed_width(
#     885     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     886 )
#     888 max_len = max(max(self.adj.len(x) for x in fmt_values), header_colwidth)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1422, in GenericArrayFormatter._format_strings(self)
#    1420 for i, v in enumerate(vals):
#    1421     if not is_float_type[i] and leading_space:
# -> 1422         fmt_values.append(f" {_format(v)}")
#    1423     elif is_float_type[i]:
#    1424         fmt_values.append(float_format(v))
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1402, in GenericArrayFormatter._format_strings.<locals>._format(x)
#    1399     return str(x)
#    1400 else:
#    1401     # object dtype
# -> 1402     return str(formatter(x))
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\printing.py:232, in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     230     result = f"'{as_escaped_string(thing)}'"
#     231 else:
# --> 232     result = as_escaped_string(thing)
#     234 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\printing.py:208, in pprint_thing.<locals>.as_escaped_string(thing, escape_chars)
#     205 else:
#     206     escape_chars = escape_chars or ()
# --> 208 result = str(thing)
#     209 for c in escape_chars:
#     210     result = result.replace(c, translate[c])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1064, in DataFrame.__repr__(self)
#    1061     return buf.getvalue()
#    1063 repr_params = fmt.get_dataframe_repr_params()
# -> 1064 return self.to_string(**repr_params)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1245, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1226 with option_context("display.max_colwidth", max_colwidth):
#    1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    (...)
#    1243         decimal=decimal,
#    1244     )
# -> 1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
#    1248         line_width=line_width,
#    1249     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1136, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1133 from pandas.io.formats.string import StringFormatter
#    1135 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136 string = string_formatter.to_string()
#    1137 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\string.py:30, in StringFormatter.to_string(self)
#      29 def to_string(self) -> str:
# ---> 30     text = self._get_string_representation()
#      31     if self.fmt.should_show_dimensions:
#      32         text = "".join([text, self.fmt.dimensions_info])
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\string.py:45, in StringFormatter._get_string_representation(self)
#      42 if self.fmt.frame.empty:
#      43     return self._empty_info_line
# ---> 45 strcols = self._get_strcols()
#      47 if self.line_width is None:
#      48     # no need to wrap around just print the whole frame
#      49     return self.adj.adjoin(1, *strcols)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\string.py:36, in StringFormatter._get_strcols(self)
#      35 def _get_strcols(self) -> list[list[str]]:
# ---> 36     strcols = self.fmt.get_strcols()
#      37     if self.fmt.is_truncated:
#      38         strcols = self._insert_dot_separators(strcols)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:617, in DataFrameFormatter.get_strcols(self)
#     613 def get_strcols(self) -> list[list[str]]:
#     614     """
#     615     Render a DataFrame to a list of columns (as lists of strings).
#     616     """
# --> 617     strcols = self._get_strcols_without_index()
#     619     if self.index:
#     620         str_index = self._get_formatted_index(self.tr_frame)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:883, in DataFrameFormatter._get_strcols_without_index(self)
#     879 cheader = str_columns[i]
#     880 header_colwidth = max(
#     881     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     882 )
# --> 883 fmt_values = self.format_col(i)
#     884 fmt_values = _make_fixed_width(
#     885     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     886 )
#     888 max_len = max(max(self.adj.len(x) for x in fmt_values), header_colwidth)
#
#     [... skipping similar frames: DataFrame.__repr__ at line 1064 (161 times), GenericArrayFormatter._format_strings.<locals>._format at line 1402 (161 times), GenericArrayFormatter._format_strings at line 1422 (161 times), pprint_thing.<locals>.as_escaped_string at line 208 (161 times), format_array at line 1328 (161 times), DataFrameFormatter.format_col at line 897 (161 times), GenericArrayFormatter.get_result at line 1359 (161 times), pprint_thing at line 232 (161 times), StringFormatter._get_strcols at line 36 (160 times), DataFrameFormatter._get_strcols_without_index at line 883 (160 times), StringFormatter._get_string_representation at line 45 (160 times), DataFrameFormatter.get_strcols at line 617 (160 times), DataFrame.to_string at line 1245 (160 times), DataFrameRenderer.to_string at line 1136 (160 times), StringFormatter.to_string at line 30 (160 times)]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1245, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1226 with option_context("display.max_colwidth", max_colwidth):
#    1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    (...)
#    1243         decimal=decimal,
#    1244     )
# -> 1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
#    1248         line_width=line_width,
#    1249     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1136, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1133 from pandas.io.formats.string import StringFormatter
#    1135 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136 string = string_formatter.to_string()
#    1137 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\string.py:30, in StringFormatter.to_string(self)
#      29 def to_string(self) -> str:
# ---> 30     text = self._get_string_representation()
#      31     if self.fmt.should_show_dimensions:
#      32         text = "".join([text, self.fmt.dimensions_info])
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\string.py:45, in StringFormatter._get_string_representation(self)
#      42 if self.fmt.frame.empty:
#      43     return self._empty_info_line
# ---> 45 strcols = self._get_strcols()
#      47 if self.line_width is None:
#      48     # no need to wrap around just print the whole frame
#      49     return self.adj.adjoin(1, *strcols)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\string.py:36, in StringFormatter._get_strcols(self)
#      35 def _get_strcols(self) -> list[list[str]]:
# ---> 36     strcols = self.fmt.get_strcols()
#      37     if self.fmt.is_truncated:
#      38         strcols = self._insert_dot_separators(strcols)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:617, in DataFrameFormatter.get_strcols(self)
#     613 def get_strcols(self) -> list[list[str]]:
#     614     """
#     615     Render a DataFrame to a list of columns (as lists of strings).
#     616     """
# --> 617     strcols = self._get_strcols_without_index()
#     619     if self.index:
#     620         str_index = self._get_formatted_index(self.tr_frame)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:883, in DataFrameFormatter._get_strcols_without_index(self)
#     879 cheader = str_columns[i]
#     880 header_colwidth = max(
#     881     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     882 )
# --> 883 fmt_values = self.format_col(i)
#     884 fmt_values = _make_fixed_width(
#     885     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     886 )
#     888 max_len = max(max(self.adj.len(x) for x in fmt_values), header_colwidth)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1422, in GenericArrayFormatter._format_strings(self)
#    1420 for i, v in enumerate(vals):
#    1421     if not is_float_type[i] and leading_space:
# -> 1422         fmt_values.append(f" {_format(v)}")
#    1423     elif is_float_type[i]:
#    1424         fmt_values.append(float_format(v))
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1402, in GenericArrayFormatter._format_strings.<locals>._format(x)
#    1399     return str(x)
#    1400 else:
#    1401     # object dtype
# -> 1402     return str(formatter(x))
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\printing.py:232, in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     230     result = f"'{as_escaped_string(thing)}'"
#     231 else:
# --> 232     result = as_escaped_string(thing)
#     234 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\printing.py:208, in pprint_thing.<locals>.as_escaped_string(thing, escape_chars)
#     205 else:
#     206     escape_chars = escape_chars or ()
# --> 208 result = str(thing)
#     209 for c in escape_chars:
#     210     result = result.replace(c, translate[c])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1064, in DataFrame.__repr__(self)
#    1061     return buf.getvalue()
#    1063 repr_params = fmt.get_dataframe_repr_params()
# -> 1064 return self.to_string(**repr_params)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1227, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1224 from pandas import option_context
#    1226 with option_context("display.max_colwidth", max_colwidth):
# -> 1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    1230         col_space=col_space,
#    1231         na_rep=na_rep,
#    1232         formatters=formatters,
#    1233         float_format=float_format,
#    1234         sparsify=sparsify,
#    1235         justify=justify,
#    1236         index_names=index_names,
#    1237         header=header,
#    1238         index=index,
#    1239         min_rows=min_rows,
#    1240         max_rows=max_rows,
#    1241         max_cols=max_cols,
#    1242         show_dimensions=show_dimensions,
#    1243         decimal=decimal,
#    1244     )
#    1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
#    1248         line_width=line_width,
#    1249     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:610, in DataFrameFormatter.__init__(self, frame, columns, col_space, header, index, na_rep, formatters, justify, float_format, sparsify, index_names, max_rows, min_rows, max_cols, show_dimensions, decimal, bold_rows, escape)
#     607 self.max_rows_fitted = self._calc_max_rows_fitted()
#     609 self.tr_frame = self.frame
# --> 610 self.truncate()
#     611 self.adj = get_adjustment()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:801, in DataFrameFormatter.truncate(self)
#     798     self._truncate_horizontally()
#     800 if self.is_truncated_vertically:
# --> 801     self._truncate_vertically()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:839, in DataFrameFormatter._truncate_vertically(self)
#     837 row_num = self.max_rows_fitted // 2
#     838 if row_num >= 1:
# --> 839     head = self.tr_frame.iloc[:row_num, :]
#     840     tail = self.tr_frame.iloc[-row_num:, :]
#     841     self.tr_frame = concat((head, tail))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:873, in _LocationIndexer._validate_tuple_indexer(self, key)
#     871 for i, k in enumerate(key):
#     872     try:
# --> 873         self._validate_key(k, i)
#     874     except ValueError as err:
#     875         raise ValueError(
#     876             "Location based indexing can only have "
#     877             f"[{self._valid_types}] types"
#     878         ) from err
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1449, in _iLocIndexer._validate_key(self, key, axis)
#    1448 def _validate_key(self, key, axis: int):
# -> 1449     if com.is_bool_indexer(key):
#    1450         if hasattr(key, "index") and isinstance(key.index, Index):
#    1451             if key.index.inferred_type == "integer":
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:124, in is_bool_indexer(key)
#      96 def is_bool_indexer(key: Any) -> bool:
#      97     """
#      98     Check whether `key` is a valid boolean indexer.
#      99
#    (...)
#     122         and convert to an ndarray.
#     123     """
# --> 124     if isinstance(key, (ABCSeries, np.ndarray, ABCIndex)) or (
#     125         is_array_like(key) and is_extension_array_dtype(key.dtype)
#     126     ):
#     127         if key.dtype == np.object_:
#     128             key_array = np.asarray(key)
#
# RecursionError: maximum recursion depth exceeded

# %%
# The .assign method is used for creating new columns

#Example:
#Some Pokemon have two types.
#Imagine I wanted to make a boolean column signifying whether or not a pokemon has more than one type
#And another column on the average attack (pokemon have regular and special attack)

pkmn.assign(
    more_than_1_type = ~ pkmn.type2.isna(),
    avg_defense = (pkmn.defense + pkmn.sp_defense)/2
)


#Example with macroeconomic data
#Making a new column for increase in population per year
econ.assign(
    pop_change = econ['pop'].diff()
)
# Out:
#        year  quarter    realgdp  realcons   realinv  realgovt  realdpi  \
# 0    1959.0      1.0   2710.349    1707.4   286.898   470.045   1886.9
# 1    1959.0      2.0   2778.801    1733.7   310.859   481.301   1919.7
# 2    1959.0      3.0   2775.488    1751.8   289.226   491.260   1916.4
# 3    1959.0      4.0   2785.204    1753.7   299.356   484.052   1931.3
# 4    1960.0      1.0   2847.699    1770.5   331.722   462.199   1955.5
# ..      ...      ...        ...       ...       ...       ...      ...
# 198  2008.0      3.0  13324.600    9267.7  1990.693   991.551   9838.3
# 199  2008.0      4.0  13141.920    9195.3  1857.661  1007.273   9920.4
# 200  2009.0      1.0  12925.410    9209.2  1558.494   996.287   9926.4
# 201  2009.0      2.0  12901.504    9189.0  1456.678  1023.528  10077.5
# 202  2009.0      3.0  12990.341    9256.0  1486.398  1044.088  10040.6
#
#          cpi      m1  tbilrate  unemp      pop  infl  realint  pop_change
# 0     28.980   139.7      2.82    5.8  177.146  0.00     0.00         NaN
# 1     29.150   141.7      3.08    5.1  177.830  2.34     0.74       0.684
# 2     29.350   140.5      3.82    5.3  178.657  2.74     1.09       0.827
# 3     29.370   140.0      4.33    5.6  179.386  0.27     4.06       0.729
# 4     29.540   139.6      3.50    5.2  180.007  2.31     1.19       0.621
# ..       ...     ...       ...    ...      ...   ...      ...         ...
# 198  216.889  1474.7      1.17    6.0  305.270 -3.16     4.33       0.787
# 199  212.174  1576.5      0.12    6.9  305.952 -8.79     8.91       0.682
# 200  212.671  1592.8      0.22    8.1  306.547  0.94    -0.71       0.595
# 201  214.469  1653.6      0.18    9.2  307.226  3.37    -3.19       0.679
# 202  216.385  1673.9      0.12    9.6  308.013  3.56    -3.44       0.787
#
# [203 rows x 15 columns]

# %%
# The .any() method useful for Truth values on columns


#Example on a series
#Suppose I wanted to check if there are any pokemon taller than 15 M
(pkmn.height_m > 20).any()


#Suppose I wanted to look at all attack types and see if there are any above a multiplier of 2

attack_eff_cols = [col_name for col_name in pkmn.columns if col_name.startswith("against")]
(pkmn[attack_eff_cols] > 2).any()     #.any only returns the colunmn and boolean series
# Out:
# against_bug          True
# against_dark         True
# against_dragon      False
# against_electric     True
# against_fairy        True
# against_fight        True
# against_fire         True
# against_flying       True
# against_ghost        True
# against_grass        True
# against_ground       True
# against_ice          True
# against_normal      False
# against_poison       True
# against_psychic      True
# against_rock         True
# against_steel        True
# against_water        True
# dtype: bool

# %%
#Example 
pkmn.loc['Chansey',:]    #this calls the column with where it finds CHANSEY
pkmn['Chansey')

# %%
# The .all() method just checks wether all rows in a column evaluate to True when given a condition

#Example:
#Suppose I really quickly wanted to check whether all pokemon had attack power
(pkmn.attack > 0).all() #On a series

#On a dataframe
(pkmn[['attack', 'defense', 'speed']] > 0).all()
# Out:
# attack     True
# defense    True
# speed      True
# dtype: bool

# %%
#The .apply() method is complicated. You can pass your own function to it.
#There are two main use cases for the apply method.

#1. Elementwise
#Imagine I wanted to make a new column that counts the number of abilities each pokemon has:
def count_abilities(x):
    #x is each element of the series
    abilities = eval(x)
    return len(abilities)

#function is an object 
#everything is an object 
pkmn.abilities.apply(count_abilities).value_counts() #On a Series

#Imagine for standardization, I wanted to uppercase all string columns
#We can manually select string columns using: string_cols = ['...']
pkmn.select_dtypes('object').apply(lambda x: x.str.upper()) #On a DataFrame   



#2. Aggregating down columns or across rows
np.round(pkmn.select_dtypes(np.number).apply(np.mean, axis=0), 2) #axis=0 means down the column
np.round(pkmn.select_dtypes(np.number).apply(np.mean, axis=1), 2) #axis=1 means across the rows
# Out:
#                        abilities capture_rate        classfication  \
# 0    ['OVERGROW', 'CHLOROPHYLL']           45         SEED POKÉMON
# 1    ['OVERGROW', 'CHLOROPHYLL']           45         SEED POKÉMON
# 2    ['OVERGROW', 'CHLOROPHYLL']           45         SEED POKÉMON
# 3       ['BLAZE', 'SOLAR POWER']           45       LIZARD POKÉMON
# 4       ['BLAZE', 'SOLAR POWER']           45        FLAME POKÉMON
# ..                           ...          ...                  ...
# 796              ['BEAST BOOST']           25       LAUNCH POKÉMON
# 797              ['BEAST BOOST']          255  DRAWN SWORD POKÉMON
# 798              ['BEAST BOOST']           15    JUNKIVORE POKÉMON
# 799              ['PRISM ARMOR']            3        PRISM POKÉMON
# 800               ['SOUL-HEART']            3   ARTIFICIAL POKÉMON
#
#         japanese_name        name    type1   type2
# 0    FUSHIGIDANEフシギダネ   BULBASAUR    GRASS  POISON
# 1     FUSHIGISOUフシギソウ     IVYSAUR    GRASS  POISON
# 2    FUSHIGIBANAフシギバナ    VENUSAUR    GRASS  POISON
# 3        HITOKAGEヒトカゲ  CHARMANDER     FIRE     NaN
# 4         LIZARDOリザード  CHARMELEON     FIRE     NaN
# ..                ...         ...      ...     ...
# 796    TEKKAGUYAテッカグヤ  CELESTEELA    STEEL  FLYING
# 797   KAMITURUGIカミツルギ     KARTANA    GRASS   STEEL
# 798   AKUZIKINGアクジキング    GUZZLORD     DARK  DRAGON
# 799     NECROZMAネクロズマ    NECROZMA  PSYCHIC     NaN
# 800      MAGEARNAマギアナ    MAGEARNA    STEEL   FAIRY
#
# [801 rows x 7 columns]

# %% [markdown]
# ### Section 2: Aggregating Data

# %% [markdown]
# "Aggregating data" just means we are summarizing it. We can aggregate data across either rows or columns.
# <br><br>
# For example, we can take the means of all columns. The mean is the summary statistic we are calculating.
#
# The most important function we will be working with is:
# <ol>
# <li> .agg() </li>
# </ol>

# %%
#A Simple way to do this without using agg
#np.number = return data that is a number
pkmn.select_dtypes(np.number)                   
pkmn.select_dtypes(np.number).mean()
pkmn.select_dtypes(np.number).sum()
pkmn.select_dtypes(np.number).nunique()



# .select_dtypes(np.number) is a Pandas method used to select columns from a DataFrame that have numeric 
# data types (e.g., integers or floats). This command filters the DataFrame to include only columns with 
# numerical values based on the specified data type criteria, which in this case is np.number, 
# representing numeric data types.
# Out:
# against_bug            5
# against_dark           5
# against_dragon         4
# against_electric       6
# against_fairy          5
# against_fight          6
# against_fire           5
# against_flying         5
# against_ghost          5
# against_grass          5
# against_ground         6
# against_ice            5
# against_normal         4
# against_poison         6
# against_psychic        6
# against_rock           5
# against_steel          5
# against_water          5
# attack               114
# base_egg_steps        10
# base_happiness         6
# base_total           203
# defense              109
# experience_growth      6
# height_m              51
# hp                    99
# percentage_male        7
# pokedex_number       801
# sp_attack            111
# sp_defense            97
# speed                113
# weight_kg            421
# generation             7
# is_legendary           1
# dtype: int64

# %% [markdown]
# But what if we wanted to use a function that Pandas doesn't have implemented as a method?
#
# We can use the .agg() method.

# %%
#.agg() takes functions or strings as parameters

#Simple example:
#Calculating basic summary stats

    # econ.agg(np.std) #Simply question. What does this return?
    # econ.agg(np.mean) #Explain why we don't use np.mean() with parentheses




#If we don't have a pandas method for it...define your own function

def range(x):
    return x.max() - x.min()
econ.iloc[:, 2:].agg(range)
# Out:
# realgdp       10704.917
# realcons       7656.200
# realinv        2004.957
# realgovt        583.688
# realdpi        8190.600
# cpi             189.630
# m1             1534.300
# tbilrate         15.210
# unemp             7.300
# pop             130.867
# infl             23.410
# realint          17.740
# pop_change        0.567
# dtype: float64

# %%
#Calculating different aggregates for different columns

econ.agg({
    'year': ['min', 'max'],
    'realgdp' : [np.mean, range],
    'unemp' : 'mean',
    'pop' : ['min', 'max', 'mean']
})
# Out:
#          year       realgdp     unemp         pop
# min    1959.0           NaN       NaN  177.146000
# max    2009.0           NaN       NaN  308.013000
# mean      NaN   7221.171901  5.884729  239.724153
# range     NaN  10704.917000       NaN         NaN

# %% [markdown]
# ___

# %%
econ.head()
# Out:
#      year  quarter   realgdp  realcons  realinv  realgovt  realdpi    cpi  \
# 0  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9  28.98
# 1  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7  29.15
# 2  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4  29.35
# 3  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3  29.37
# 4  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5  29.54
#
#       m1  tbilrate  unemp      pop  infl  realint
# 0  139.7      2.82    5.8  177.146  0.00     0.00
# 1  141.7      3.08    5.1  177.830  2.34     0.74
# 2  140.5      3.82    5.3  178.657  2.74     1.09
# 3  140.0      4.33    5.6  179.386  0.27     4.06
# 4  139.6      3.50    5.2  180.007  2.31     1.19

# %% [markdown]
# ### Section 3: GroupBy

# %% [markdown]
# Now it gets even better. We can do more complicated aggregates by grouping by columns.

# %%
pkmn.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
def find_mode(x):
    return x.value_counts().idxmax() #How do you think this code works?
    
    
pkmn.groupby('is_legendary').agg({
    'height_m' : np.mean,
    'attack' : np.mean,
    'speed' : np.mean,
    'defense' : np.mean,
    'generation' : find_mode
})
# Out:
#               height_m     attack      speed    defense  generation
# is_legendary
# 1             1.163892  77.857678  66.334582  73.008739           5

# %%
#Another example:
#Average interest rate by year
econ.groupby('year').agg({     #groupby column year and apply mean condition on colum realint 
    'realint':np.mean})


# fig, ax = plt.subplots(figsize=(10, 5))
# econ.groupby('year').agg({
#     'realint':np.mean}).plot(ax=ax)
# plt.title('Average Real Interest Rate per Year')

#this is a dataframe and you can PLOT off datafrom ,plot
#type(econ.groupby('year').agg({
#    'realint':np.mean}))
# Out:
#          realint
# year
# 1959.0  1.472500
# 1960.0  1.120000
# 1961.0  1.725000
# 1962.0  1.467500
# 1963.0  1.582500
# 1964.0  2.477500
# 1965.0  2.112500
# 1966.0  1.725000
# 1967.0  0.747500
# 1968.0  0.845000
# 1969.0  0.832500
# 1970.0  0.962500
# 1971.0  1.040000
# 1972.0  0.665000
# 1973.0 -1.940000
# 1974.0 -3.407500
# 1975.0 -0.817500
# 1976.0 -0.115000
# 1977.0 -1.172500
# 1978.0 -1.417500
# 1979.0 -2.697500
# 1980.0  0.535000
# 1981.0  5.860000
# 1982.0  6.605000
# 1983.0  4.497500
# 1984.0  5.962500
# 1985.0  3.525000
# 1986.0  4.485000
# 1987.0  1.760000
# 1988.0  2.487500
# 1989.0  2.990000
# 1990.0  1.882500
# 1991.0  2.535000
# 1992.0  0.162500
# 1993.0  0.575000
# 1994.0  1.645000
# 1995.0  2.680000
# 1996.0  2.017500
# 1997.0  3.445000
# 1998.0  3.065000
# 1999.0  1.967500
# 2000.0  2.150000
# 2001.0  1.907500
# 2002.0 -1.157500
# 2003.0 -1.020000
# 2004.0 -1.417500
# 2005.0 -0.580000
# 2006.0  2.715000
# 2007.0 -0.122500
# 2008.0  1.297500
# 2009.0 -2.446667

# %%
#Another example:
#By quarter average consumption spending

(econ.groupby('quarter').agg({'realcons': 'mean'}) / 4000).plot(kind='bar')
plt.ylim(0, 1.5)
plt.title('Average Real Consumption Per Quarter')
# Out:
# (0.0, 1.5)

# %% [markdown]
# #### Rolling and Expanding Windows

# %%
#import the tsla dataset
btc = pd.read_csv('bitcoin.csv', parse_dates=True)
btc.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-10-01  100.000000  100.000000  100.000000  100.000000  100.000000
# 1  2020-10-02  100.000000  100.000000  100.000000  100.000000  100.000000
# 2  2020-10-05  100.029999  100.040001   99.995003   99.995003   99.995003
# 3  2020-10-06  100.010002  100.029999  100.010002  100.029999  100.029999
# 4  2020-10-07   99.949997   99.959999   99.919998   99.919998   99.919998
#
#    Volume
# 0       0
# 1       0
# 2   10725
# 3   10080
# 4    6350

# %%
#Example:

#Investments
#Imagine I was investing in Bitcoin

#Rolling windows can be useful for calculating cumulative return
#Return over two periods is the cumulative product

btc['Gross Daily Return'] = btc.Close.pct_change() + 1
btc = btc.assign(
Gross_Daily_Return = btc.Close.pct_change() + 1,
Cumulative_Gross_Return = lambda x: x['Gross Daily Return'].cumprod()
)

#Then the amount I have at time step i, would be C_i*CGR_t
plt.plot(btc.Cumulative_Gross_Return * 100)

#The above .cumprod is just using the expanding window. It is equivalent to
btc.Gross_Daily_Return.expanding().apply(lambda s: s.cumprod().iat[-1])



#Another example: Expanding windows can be useful for calculating High watermark
#The high watermark is the highest investment value up to the time t

(btc.Cumulative_Gross_Return * 100).expanding().max()
# Out:
# 0             NaN
# 1      100.000000
# 2      100.000000
# 3      100.029999
# 4      100.029999
#           ...
# 732    100.154999
# 733    100.154999
# 734    100.154999
# 735    100.154999
# 736    100.154999
# Name: Cumulative_Gross_Return, Length: 737, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# ### Section 4: Time Series

# %% [markdown]
# Time is a complicated subject in computer science.
# <br>
# We won't worry about timezones.
# <br> <br>
# Python has a standard (built-in) module called datetime. See this doc page for comprehensive information: https://docs.python.org/3/library/datetime.html

# %%
import datetime as dt

# %% [markdown]
# The most important classes for you to know in this module are:
# <ol>
# <li> datetime.date (year, month, day) </li>
# <li> datetime.time (hour, minute, second, microsecond, tzinfo) </li>
# <li> datetime.datetime : A combination of a date and a time </li>
# <li> datetime.timedelta : A duration expressing the difference between two date, time or datetime instances to microsecond resolution</li>
# </ol>

# %%
#Example: Our bitcoin dataset
btc.Date = pd.to_datetime(btc.Date)
#We can take a look at its elements
btc.Date.iat[0]
btc.Date.iat[0].date()
# Out:
# datetime.date(2020, 10, 1)

# %%
#Now you can groupby
quarterly_stds = btc.groupby(pd.Grouper(key='Date', freq='Q')).std() #The standard deviation per quarter
quarterly_stds
# Out:
#                 Open      High       Low     Close  Adj Close        Volume
# Date
# 2020-12-31  0.112726  0.112392  0.112881  0.112214   0.112214  15800.466179
# 2021-03-31  0.554986  0.549480  0.553691  0.548705   0.548705   1274.127625
# 2021-06-30  0.283721  0.276405  0.165209  0.147611   0.147611   1560.301048
# 2021-09-30  0.253828  0.256272  0.250945  0.253535   0.253535  15979.250751
# 2021-12-31  0.212006  0.210650  0.214023  0.208471   0.208471  44558.359775
# 2022-03-31  1.031406  1.028500  1.024860  1.020329   1.020329  66005.551248
# 2022-06-30  0.699860  0.718829  0.709961  0.710866   0.710866   2916.474494
# 2022-09-30  1.191883  1.176126  1.222926  1.207322   1.207322   2946.670024
# 2022-12-31  0.916842  0.924495  0.909885  0.918562   0.918562   4313.384751
# 2023-03-31  0.759492  0.761253  0.757034  0.756769   0.756769   1985.453045
# 2023-06-30  0.531677  0.537372  0.523755  0.524885   0.524885  24341.378762
# 2023-09-30  0.389993  0.403039  0.385942  0.394102   0.394102  10586.913671

# %%
import matplotlib.dates as mdates

fig, ax = plt.subplots(figsize=(10, 5))
quarterly_stds.Close.plot()
plt.title("Quarterly Standard Deviations of Bitcoin Price")
# Out:
# Text(0.5, 1.0, 'Quarterly Standard Deviations of Bitcoin Price')

# %% [markdown]
# ### Joins: (If we have time)
